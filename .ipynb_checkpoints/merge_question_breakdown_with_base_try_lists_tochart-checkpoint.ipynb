# %%
#Dependencies
import pandas as pd
import numpy as np
import csv
import os
import matplotlib.pyplot as plt
import scipy.stats
# %matplotlib notebook
#Read in CSV file and merge them
#alcohol_data_csv=os.path.join('U.S._Chronic_Disease_Indicators__Alcohol.csv')
#alcohol_data=pd.read_csv(alcohol_data_csv).encode('utf-8')

#question_breakdown_csv=("Question_breakdown_w_age_CMT.csv")
#question_breakdown_data=pd.read_csv(question_breakdown_csv)




#merged_data=pd.merge(alcohol_data,question_breakdown_data,on="Question")
#merged_data.head()

# %%
#merged_data.columns

# %%
#merged_data_edited=merged_data[["YearStart","LocationDesc","DataValue","DataValueUnit", "DataValueType",\
                                #"StratificationCategory1","Stratification1","Binge_Heavy","Description", "Sex","Age",\
                                #"Question_additional_comments","DataSource","Topic","Question"]]
#merged_data_edited.head()

# %%
#merged_data_edited.to_csv("merged_data_edited.csv")

# %%
merged_data_new_csv=("merged_data_edited.csv")
merged_data_new=pd.read_csv(merged_data_new_csv)
#merged_data_new.head()

# %%
#Convert % into one column if DataValue = percent
dataVal_w_units=merged_data_new["DataValue"]+ " " + merged_data_new["DataValueUnit"]
merged_data_new['DataVal with Units']=dataVal_w_units
#merged_data_new.columns

# %%
#Add sex_age category for Gender with Sex column
sex_adults=merged_data_new.loc[(merged_data_new["Sex"] == "Adults")\
                               & (merged_data_new["StratificationCategory1"] == "Gender")\
                               & (merged_data_new["LocationDesc"]== "United States")\
                               & (merged_data_new["DataValueType"]== "Crude Prevalence")
                               & (merged_data_new["Binge_Heavy"]== "Binge")
                               ,["YearStart","DataValue","Stratification1","Age","Sex","StratificationCategory1",\
                                 "LocationDesc","DataValueType"]]

#Sex_Age_Calc
sex_age=sex_adults["Stratification1"] + " "  + sex_adults["Age"]
sex_adults['sex_age']=sex_age
sex_adults_agesex=sex_adults[["YearStart","DataValue","sex_age"]]

#Add sex_age category for NOT Adultsfor reverse Concatenate 

sex_not_adults=merged_data_new.loc[(merged_data_new["Sex"] != "Adults")\
                                   &(merged_data_new["StratificationCategory1"] == "Overall")\
                                   & (merged_data_new["LocationDesc"]== "United States")\
                                   & (merged_data_new["DataValueType"]== "Crude Prevalence")\
                                   & (merged_data_new["Binge_Heavy"]== "Binge")
                                   ,:]

sex_not_adults_agesex=sex_not_adults[["YearStart","DataValue","Age","Sex"]]
sex_age=sex_not_adults["Sex"] + " "  +sex_not_adults["Age"]
sex_not_adults_agesex['sex_age']=sex_age
sex_not_adults_agesex=sex_not_adults_agesex[["YearStart","DataValue","sex_age"]]

#Merge Data
chart1_data_base=pd.merge(sex_adults_agesex,sex_not_adults_agesex,how="outer")
chart1_data_base["DataValue"]=chart1_data_base["DataValue"].astype(float)
# Out:
# C:\Users\Craig\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Divide up Data by Ages Range

####  Male 18 or over
c1_Male_18_over=chart1_data_base.loc[chart1_data_base["sex_age"] =="Male >=18",:]
c1_Male_18_over=c1_Male_18_over.sort_values("YearStart")

c1_Male_18_over_yrst=[]
c1_Male_18_over_yrst.append(c1_Male_18_over["YearStart"])
c1_Male_18_over_yrst.index_reset()

c1_Male_18_over_dataval=[]
c1_Male_18_over_dataval.append(c1_Male_18_over["DataValue"])

c1_Male_18_over_sexage=[]
c1_Male_18_over_sexage.append(c1_Male_18_over["sex_age"])

#c1_male,=plt.plot(c1_Male_18_over_yrst,c1_Male_18_over_dataval,color="red")
c1_Male_18_over_sexage[]
# Out:
#   File "<ipython-input-55-0b3f5881521d>", line 18
#     c1_Male_18_over_sexage[]
#                            ^
# SyntaxError: invalid syntax

# %%
####  Female 18 or over
c1_Female_18_over=chart1_data_base.loc[chart1_data_base["sex_age"] =="Female >=18",:]
c1_Female_18_over=c1_Female_18_over.sort_values("YearStart")
c1_Female_18_over.plot(x="YearStart",y="DataValue",color="blue",secondary_y=True)

####  Female 18 to 44
c1_Women_18_44=chart1_data_base.loc[chart1_data_base["sex_age"] == "Women 18-44",:]
c1_Women_18_44=c1_Women_18_44.sort_values("YearStart")
c1_Women_18_44.plot(x="YearStart",y="DataValue",color="blue")

####  Youth 14-18
c1_Youth_14_18=chart1_data_base.loc[chart1_data_base["sex_age"] =="Youth 14 to 18",:]
c1_Youth_14_18=c1_Youth_14_18.sort_values("YearStart")
c1_Youth_14_18.plot(x="YearStart",y="DataValue",color="green")

c1_Male_18_over_yrst
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# [7     2011
#  5     2012
#  11    2013
#  9     2014
#  3     2015
#  0     2016
#  Name: YearStart, dtype: int64]

# %% [markdown]
# Items open above
# last chart needs to have zero decimals
# also, should only have 2 data points

# %%
cht2=merged_data_new
#Sex_Age_Calc
sex_age=cht2["Stratification1"] + " "  + cht2["Age"]
cht2['sex_age']=sex_age


#Add sex_age category for Gender with Sex column
intensity_drinking=cht2.loc[(merged_data_new["Description"] == "intensity")\
                               & (merged_data_new["LocationDesc"]== "United States")\
                               & (merged_data_new["DataValueType"]== "Mean")
                               ,["YearStart","DataValue","Stratification1","Age","Sex","StratificationCategory1",\
                                 "LocationDesc","DataValueType","sex_age"]]

intensity_drinking["DataValue"]=intensity_drinking["DataValue"].astype(float)
#intensity_drinking.dtypes

intensity_drinking_chart=intensity_drinking[["YearStart","DataValue","sex_age"]]

# %%
#Divide up Data by Ages Range
c2_Male_18_over=intensity_drinking_chart.loc[intensity_drinking_chart["sex_age"] =="Male >=18",:]
c2_Male_18_over=c2_Male_18_over.sort_values("YearStart")
c2_Male_18_over.plot.line(x="YearStart",y="DataValue",color="red")

c2_Female_18_over=intensity_drinking_chart.loc[intensity_drinking_chart["sex_age"] =="Female >=18",:]
c2_Female_18_over=c2_Female_18_over.sort_values("YearStart")
c2_Female_18_over.plot.line(x="YearStart",y="DataValue",color="blue")

c2_Overall_18_over=intensity_drinking_chart.loc[intensity_drinking_chart["sex_age"] =="Overall >=18",:]
c2_Overall_18_over=c2_Overall_18_over.sort_values("YearStart")
c2_Overall_18_over.plot.line(x="YearStart",y="DataValue",color="green")

# %%
cht3=merged_data_new

#Sex_Age_Calc
sex_age=cht2["Stratification1"] + " "  + cht2["Age"]
cht3['sex_age']=sex_age


#Add sex_age category for Gender with Sex column
frequency_drinking=cht2.loc[(merged_data_new["Description"] == "intensity")\
                               & (merged_data_new["LocationDesc"]== "United States")\
                               & (merged_data_new["DataValueType"]== "Mean")
                               ,["YearStart","DataValue","Stratification1","Age","Sex","StratificationCategory1",\
                                 "LocationDesc","DataValueType","sex_age"]]


frequency_drinking["DataValue"]=frequency_drinking["DataValue"].astype(float)

frequency_drinking.dtypes

frequency_drinking_chart=frequency_drinking[["YearStart","DataValue","sex_age"]]

# %%
#Divide up Data by Ages Range
c3_Male_18_over=frequency_drinking_chart.loc[frequency_drinking_chart["sex_age"] =="Male >=18",:]
c3_Male_18_over=c3_Male_18_over.sort_values("YearStart")
c3_Male_18_over=c3_Male_18_over.reset_index()
c3_Male_18_overplt = c3_Male_18_over.plot.line(x="YearStart",y="DataValue",color="red")

c3_Female_18_over=frequency_drinking_chart.loc[frequency_drinking_chart["sex_age"] =="Female >=18",:]
c3_Female_18_over= c3_Female_18_over.sort_values("YearStart")
c3_Female_18_over.reset_index()
c3_Female_18_overplt= c3_Female_18_over.plot.line(x="YearStart",y="DataValue",color="blue")

c3_Overall_18_over=frequency_drinking_chart.loc[frequency_drinking_chart["sex_age"] =="Overall >=18",:]
c3_Overall_18_over=c3_Overall_18_over.sort_values("YearStart")
c3_Overall_18_over.reset_index()
c3_Overall_18_overplt = c3_Overall_18_over.plot.line(x="YearStart",y="DataValue",color="green")
# Out:
#    index  YearStart  DataValue    sex_age
# 0   8635       2011        8.8  Male >=18
# 1   7766       2012        8.6  Male >=18
# 2  10376       2013        8.7  Male >=18
# 3   9505       2014        8.6  Male >=18
# 4   6894       2015        8.5  Male >=18
# 5   5330       2016        8.5  Male >=18

# %%
c3_Male_18_over.reset_index()
# Out:
#    index  YearStart  DataValue    sex_age
# 0   8635       2011        8.8  Male >=18
# 1   7766       2012        8.6  Male >=18
# 2  10376       2013        8.7  Male >=18
# 3   9505       2014        8.6  Male >=18
# 4   6894       2015        8.5  Male >=18
# 5   5330       2016        8.5  Male >=18

# %%
c3_Male_18_over.columns
# Out:
# Index(['YearStart', 'DataValue', 'sex_age'], dtype='object')

# %%
cht4=merged_data_new
cht4.columns
# Out:
# Index(['Unnamed: 0', 'YearStart', 'LocationDesc', 'DataValue', 'DataValueUnit',
#        'DataValueType', 'StratificationCategory1', 'Stratification1',
#        'Binge_Heavy', 'Description', 'Sex', 'Age',
#        'Question_additional_comments', 'DataSource', 'Topic', 'Question',
#        'DataVal with Units', 'sex_age'],
#       dtype='object')
