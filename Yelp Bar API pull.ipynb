# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time
import json
import seaborn
from scipy.stats import ttest_ind
from pprint import pprint 

# Yelp API Key
ykey_id = "1GwZyE0zIjSujpHtlMnodQ"
ykey_secret = "mcTmghB48JIH0xoNWLldvsX9uIiOLQfdi0gR8LWdFt02lboCAF9vxSSd1MI0KtZ0"
ykey_access_token = "gl6k6JmewUhzjMVBv0I2x4Bz_NRiEggSqjlGbTaejmbzvBJXgI36FPgWoqBnEL9QQ6wU5H4h41dxPkxVjHFlawtH69m1kcXQuHev5PuWBtcdBEAbdJR0HNl3d4tpWXYx"

# %%
# Create Two DataFrames to store the Italian and the Mexican Data 
Bar_data = pd.DataFrame();

var_zip_code=["08003","19103"]
counter=0

# Setup the DataFrames to have appropriate columns
Bar_data["Zip Code"] = ""
Bar_data["Bar Review Count"] = ""
Bar_data["Bar Average Rating"] = ""
Bar_data["Bar Weighted Rating"] = ""

# Include Yelp Token
headers = {"Authorization": "Bearer gl6k6JmewUhzjMVBv0I2x4Bz_NRiEggSqjlGbTaejmbzvBJXgI36FPgWoqBnEL9QQ6wU5H4h41dxPkxVjHFlawtH69m1kcXQuHev5PuWBtcdBEAbdJR0HNl3d4tpWXYx"}
counter = 0


# Loop through every zip code
for zip in var_zip_code:
    
    # Add to counter
    counter = counter + 1
    
    # Create two endpoint URLs:
    target_url_bars_by_zip = "https://api.yelp.com/v3/businesses/search?term=Bars&location=%s" % (var_zip_code)
    
    
    # Print the URLs to ensure logging
    print(counter)
    print(target_url_bars_by_zip)
    
   # Get the Yelp Reviews
    yelp_reviews_bars_by_zip = requests.get(target_url_bars_by_zip, headers=headers).json()
    
    pprint(yelp_reviews_bars_by_zip)
    
    # Calculate the total reviews and weighted rankings
    #bar_review_count = 0
    #bar_weighted_review = 0

    
    try:
        
        # Loop through all records to calculate the review count and weighted review value
        for business in yelp_reviews_bars_by_zip["businesses"]:
            
            Bar_review_count = Bar_review_count + business["review_count"]
            Bar_weighted_review = Bar_weighted_review + business["review_count"] * business["rating"]

        
            # Append the data to the appropriate column of the data frames
            Bar_data.set_value("Zip Code", var_zip_code)
            Bar_data.set_value("Bar Review Count", Bar_review_count)
            Bar_data.set_value("Bar Average Rating", Bar_weighted_review / Bar_review_count)
            Bar_data.set_value("Bar Weighted Rating", Bar_weighted_review)
    except:
        print("Uh oh")
# Out:
# 1
# https://api.yelp.com/v3/businesses/search?term=Bars&location=['08003', '19103']
# {'businesses': [{'alias': 'forgotten-boardwalk-brewing-cherry-hill',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 39.9122883,
#                                  'longitude': -74.9692065},
#                  'display_phone': '(856) 437-0709',
#                  'distance': 2573.0442243758944,
#                  'id': 'Zr3CwG-1zbXlktQoHjgIOQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ssnAKM6EMTFBUt2U-J5XFQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1940 Olney Ave',
#                               'address2': 'Ste 100',
#                               'address3': '',
#                               'city': 'Cherry Hill',
#                               'country': 'US',
#                               'display_address': ['1940 Olney Ave',
#                                                   'Ste 100',
#                                                   'Cherry Hill, NJ 08003'],
#                               'state': 'NJ',
#                               'zip_code': '08003'},
#                  'name': 'Forgotten Boardwalk Brewing',
#                  'phone': '+18564370709',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 77,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/forgotten-boardwalk-brewing-cherry-hill?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'zeds-beer-bado-brewing-evesham-township',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 39.8921552048509,
#                                  'longitude': -74.9217946980322},
#                  'display_phone': '(856) 872-7632',
#                  'distance': 3923.0391867090043,
#                  'id': '5TJzhqoLXvWXyxHFullsJg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zLgVLA04CQbXOHDHQupxkw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '19 N Maple Ave',
#                               'address2': 'Unit B',
#                               'address3': None,
#                               'city': 'Evesham Township',
#                               'country': 'US',
#                               'display_address': ['19 N Maple Ave',
#                                                   'Unit B',
#                                                   'Evesham Township, NJ 08053'],
#                               'state': 'NJ',
#                               'zip_code': '08053'},
#                  'name': "Zed's Beer Bado Brewing",
#                  'phone': '+18568727632',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 24,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/zeds-beer-bado-brewing-evesham-township?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'jays-elbow-room-maple-shade',
#                  'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#                  'coordinates': {'latitude': 39.93853, 'longitude': -74.97037},
#                  'display_phone': '(856) 235-3687',
#                  'distance': 5480.079751798534,
#                  'id': 'Vz87mSBJUQUEnDsYtkFPfg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sEwFIz3W94B8XtPmFKMI9A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2806 Route 73 N',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Maple Shade',
#                               'country': 'US',
#                               'display_address': ['2806 Route 73 N',
#                                                   'Maple Shade, NJ 08052'],
#                               'state': 'NJ',
#                               'zip_code': '08052'},
#                  'name': "Jay's Elbow Room",
#                  'phone': '+18562353687',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 99,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/jays-elbow-room-maple-shade?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'chickies-and-petes-marlton',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'sportsbars',
#                                  'title': 'Sports Bars'}],
#                  'coordinates': {'latitude': 39.891412, 'longitude': -74.92689},
#                  'display_phone': '(856) 452-5126',
#                  'distance': 3483.2252184634926,
#                  'id': 'kvv4hZ8EUe_sGwcsl-mLQw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FoUSJJILiPObbWCG2mdMPQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '25 NJ-73',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Marlton',
#                               'country': 'US',
#                               'display_address': ['25 NJ-73',
#                                                   'Marlton, NJ 08053'],
#                               'state': 'NJ',
#                               'zip_code': '08053'},
#                  'name': "Chickie's & Pete's",
#                  'phone': '+18564525126',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 84,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/chickies-and-petes-marlton?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'yard-house-moorestown-2',
#                  'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'vegetarian', 'title': 'Vegetarian'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 39.942683769952,
#                                  'longitude': -74.9628652384746},
#                  'display_phone': '(856) 722-5620',
#                  'distance': 5963.0351388471745,
#                  'id': 'JNBuXPEjE3eavcIUvUc49A',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QBM9bgIRcTBmlSSYgQeYkQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '400 Rte 38',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Moorestown',
#                               'country': 'US',
#                               'display_address': ['400 Rte 38',
#                                                   'Moorestown, NJ 08057'],
#                               'state': 'NJ',
#                               'zip_code': '08057'},
#                  'name': 'Yard House',
#                  'phone': '+18567225620',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 351,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/yard-house-moorestown-2?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'the-pour-house-westmont',
#                  'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 39.910558,
#                                  'longitude': -75.050601},
#                  'display_phone': '(856) 869-4600',
#                  'distance': 7475.732147033148,
#                  'id': 'f8MSbvd5JotxsFsS6fbl-Q',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/e1nY241N2_o4G12ImMsmUA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '124 Haddon Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Westmont',
#                               'country': 'US',
#                               'display_address': ['124 Haddon Ave',
#                                                   'Westmont, NJ 08108'],
#                               'state': 'NJ',
#                               'zip_code': '08108'},
#                  'name': 'The Pour House',
#                  'phone': '+18568694600',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 386,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-pour-house-westmont?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': '7-tap-tavern-mount-laurel',
#                  'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 39.9228164800945,
#                                  'longitude': -74.9352104589343},
#                  'display_phone': '(856) 235-2118',
#                  'distance': 4650.542755527036,
#                  'id': 'DOVvbLt2HDGPnVCYU7IL2Q',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aZBOTbha1njXWsomokhJ9Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '200 Country Club Dr',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Mount Laurel',
#                               'country': 'US',
#                               'display_address': ['200 Country Club Dr',
#                                                   'Mount Laurel, NJ 08054'],
#                               'state': 'NJ',
#                               'zip_code': '08054'},
#                  'name': '7 Tap Tavern',
#                  'phone': '+18562352118',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 5,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/7-tap-tavern-mount-laurel?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'tir-na-nog-kitchen-and-irish-pub-cherry-hill',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#                  'coordinates': {'latitude': 39.864049,
#                                  'longitude': -74.964849},
#                  'display_phone': '(856) 520-8312',
#                  'distance': 2781.0683944251164,
#                  'id': 'ODJi28l49yt15sEYqwE6Nw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bALUx-YUounW9xbGyEqETA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '482 E Evesham Rd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Cherry Hill',
#                               'country': 'US',
#                               'display_address': ['482 E Evesham Rd',
#                                                   'Cherry Hill, NJ 08003'],
#                               'state': 'NJ',
#                               'zip_code': '08003'},
#                  'name': 'Tir Na Nog Kitchen & Irish Pub',
#                  'phone': '+18565208312',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 78,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/tir-na-nog-kitchen-and-irish-pub-cherry-hill?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'kings-road-brewing-company-haddonfield',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 39.89787, 'longitude': -75.03281},
#                  'display_phone': '',
#                  'distance': 5645.756369986817,
#                  'id': 'VstEcA4Mpr-Z_Z7YxGonjw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Zl1Ur5J_u7E4YoXV8K1vuA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '127 Kings Hwy E',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Haddonfield',
#                               'country': 'US',
#                               'display_address': ['127 Kings Hwy E',
#                                                   'Haddonfield, NJ 08033'],
#                               'state': 'NJ',
#                               'zip_code': '08033'},
#                  'name': 'Kings Road Brewing Company',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 12,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kings-road-brewing-company-haddonfield?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'p-j-whelihans-pub-restaurant-cherry-hill-cherry-hill-7',
#                  'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 39.90528, 'longitude': -74.97209},
#                  'display_phone': '(856) 424-8844',
#                  'distance': 1847.993138021452,
#                  'id': '6JHO6E6brnJOPK5476QY6A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UVmkc8pioU3RD0P7j0S9tw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1854 E Marlton Pike',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Cherry Hill',
#                               'country': 'US',
#                               'display_address': ['1854 E Marlton Pike',
#                                                   'Cherry Hill, NJ 08034'],
#                               'state': 'NJ',
#                               'zip_code': '08034'},
#                  'name': "P.J. Whelihan's Pub + Restaurant - Cherry Hill",
#                  'phone': '+18564248844',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 144,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/p-j-whelihans-pub-restaurant-cherry-hill-cherry-hill-7?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'timeout-entertainment-and-grill-barrington',
#                  'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'musicvenues',
#                                  'title': 'Music Venues'}],
#                  'coordinates': {'latitude': 39.872852,
#                                  'longitude': -75.045364},
#                  'display_phone': '(856) 547-7444',
#                  'distance': 6887.849915596487,
#                  'id': 'X0KU6OBAW9I1QFsFBq-Jhg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PrJVmYCqtxZuK7sANoy4pQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '241 White Horse Pike',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Barrington',
#                               'country': 'US',
#                               'display_address': ['241 White Horse Pike',
#                                                   'Barrington, NJ 08007'],
#                               'state': 'NJ',
#                               'zip_code': '08007'},
#                  'name': 'Timeout Entertainment and Grill',
#                  'phone': '+18565477444',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 13,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/timeout-entertainment-and-grill-barrington?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'flying-fish-brewing-co-somerdale',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 39.8536587887811,
#                                  'longitude': -75.0204055374678},
#                  'display_phone': '(856) 504-3442',
#                  'distance': 5991.588405336659,
#                  'id': 'K3rQIh4EXBwCb1xass2k7g',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/L7b7ZZu3W4Ppx5s6dTSdMQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '900 Kennedy Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Somerdale',
#                               'country': 'US',
#                               'display_address': ['900 Kennedy Blvd',
#                                                   'Somerdale, NJ 08083'],
#                               'state': 'NJ',
#                               'zip_code': '08083'},
#                  'name': 'Flying Fish Brewing Co',
#                  'phone': '+18565043442',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 73,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/flying-fish-brewing-co-somerdale?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'otts-voorhees-tavern-voorhees-township-2',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'sportsbars',
#                                  'title': 'Sports Bars'}],
#                  'coordinates': {'latitude': 39.8483192063396,
#                                  'longitude': -74.9789591129339},
#                  'display_phone': '(856) 282-6309',
#                  'distance': 4645.612119029087,
#                  'id': 'ZQauNoMxMbdeq3WpE8PLew',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ia33m-58nKjWosfjbhza8g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '890 Haddonfield Berlin Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Voorhees Township',
#                               'country': 'US',
#                               'display_address': ['890 Haddonfield Berlin Rd',
#                                                   'Voorhees Township, NJ '
#                                                   '08043'],
#                               'state': 'NJ',
#                               'zip_code': '08043'},
#                  'name': "Ott's Voorhees Tavern",
#                  'phone': '+18562826309',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 53,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/otts-voorhees-tavern-voorhees-township-2?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'millers-ale-house-mt-laurel-mt-laurel-2',
#                  'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 39.9315248006976,
#                                  'longitude': -74.9596953392029},
#                  'display_phone': '(856) 722-5690',
#                  'distance': 4756.635698026076,
#                  'id': '7McQCpcpjyAA_TaQPlsirg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YD5HN5k0E_lMv-GktPdVLQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '554 Fellowship Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mt Laurel',
#                               'country': 'US',
#                               'display_address': ['554 Fellowship Rd',
#                                                   'Mt Laurel, NJ 08054'],
#                               'state': 'NJ',
#                               'zip_code': '08054'},
#                  'name': "Miller's Ale House - Mt Laurel",
#                  'phone': '+18567225690',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 261,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/millers-ale-house-mt-laurel-mt-laurel-2?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'marlton-tavern-marlton',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 39.89015, 'longitude': -74.91717},
#                  'display_phone': '(856) 985-2424',
#                  'distance': 4312.949883363522,
#                  'id': '4ZkITH77rCe0h6hEm9VV4g',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2qgraAAlm-qmEn9iLyJWwQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '65 E Main St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Marlton',
#                               'country': 'US',
#                               'display_address': ['65 E Main St',
#                                                   'Marlton, NJ 08053'],
#                               'state': 'NJ',
#                               'zip_code': '08053'},
#                  'name': 'Marlton Tavern',
#                  'phone': '+18569852424',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 70,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/marlton-tavern-marlton?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'iron-hill-brewery-and-restaurant-voorhees',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 39.851736,
#                                  'longitude': -74.998271},
#                  'display_phone': '(856) 545-9009',
#                  'distance': 4917.461510267735,
#                  'id': 'T-uphPk44OFt6sR8F-0uHA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WmmiqMzq6giNTUodV3U4xA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '13107 Town Center Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Voorhees',
#                               'country': 'US',
#                               'display_address': ['13107 Town Center Blvd',
#                                                   'Voorhees, NJ 08043'],
#                               'state': 'NJ',
#                               'zip_code': '08043'},
#                  'name': 'Iron Hill Brewery & Restaurant',
#                  'phone': '+18565459009',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 223,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/iron-hill-brewery-and-restaurant-voorhees?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'kaminskis-sports-bar-and-grill-cherry-hill',
#                  'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 39.8919, 'longitude': -75.01846},
#                  'display_phone': '(856) 428-2555',
#                  'distance': 4331.415433338389,
#                  'id': 'DI4OK-UVHZqCwpCE8jX2ow',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/i1z6UdoGXj8suZt9FBCI4A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1424 Brace Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Cherry Hill',
#                               'country': 'US',
#                               'display_address': ['1424 Brace Rd',
#                                                   'Cherry Hill, NJ 08034'],
#                               'state': 'NJ',
#                               'zip_code': '08034'},
#                  'name': "Kaminski's Sports Bar and Grill",
#                  'phone': '+18564282555',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 91,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kaminskis-sports-bar-and-grill-cherry-hill?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'iron-hill-brewery-and-restaurant-maple-shade',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 39.947169125849,
#                                  'longitude': -74.973307338977},
#                  'display_phone': '(856) 273-0300',
#                  'distance': 6466.278602676599,
#                  'id': '5KS5b5-ip8znhJS_CYdzeQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C-C8MLVF4vV8vv8R8RusPQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '124 East Kings Hwy',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Maple Shade',
#                               'country': 'US',
#                               'display_address': ['124 East Kings Hwy',
#                                                   'Maple Shade, NJ 08052'],
#                               'state': 'NJ',
#                               'zip_code': '08052'},
#                  'name': 'Iron Hill Brewery & Restaurant',
#                  'phone': '+18562730300',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 299,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/iron-hill-brewery-and-restaurant-maple-shade?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'brewers-towne-tavern-westmont',
#                  'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#                  'coordinates': {'latitude': 39.908546,
#                                  'longitude': -75.046142},
#                  'display_phone': '(856) 854-5545',
#                  'distance': 7032.041763757266,
#                  'id': '9I15RdM5Dvgx-fSgC5LW8A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UDuE1F4QtZYM5AqWeRCH5w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '239 Haddon Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Westmont',
#                               'country': 'US',
#                               'display_address': ['239 Haddon Ave',
#                                                   'Westmont, NJ 08108'],
#                               'state': 'NJ',
#                               'zip_code': '08108'},
#                  'name': 'Brewers Towne Tavern',
#                  'phone': '+18568545545',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 42,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/brewers-towne-tavern-westmont?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'the-taproom-and-grill-haddon-township',
#                  'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#                                 {'alias': 'pubs', 'title': 'Pubs'}],
#                  'coordinates': {'latitude': 39.9001269395344,
#                                  'longitude': -75.0530919996334},
#                  'display_phone': '(856) 854-4255',
#                  'distance': 7393.199106058444,
#                  'id': 'ho7GpzsVdUi9ndG3Z4LuuA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UP-4KmZ3oErvTOk0K4uy_w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '427 W Crystal Lake Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Haddon Township',
#                               'country': 'US',
#                               'display_address': ['427 W Crystal Lake Ave',
#                                                   'Haddon Township, NJ 08033'],
#                               'state': 'NJ',
#                               'zip_code': '08033'},
#                  'name': 'The Taproom & Grill',
#                  'phone': '+18568544255',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 94,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-taproom-and-grill-haddon-township?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'}],
#  'region': {'center': {'latitude': 39.88918063619376,
#                        'longitude': -74.96761322021484}},
#  'total': 76}
# Uh oh
# 2
# https://api.yelp.com/v3/businesses/search?term=Bars&location=['08003', '19103']
# {'businesses': [{'alias': 'forgotten-boardwalk-brewing-cherry-hill',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 39.9122883,
#                                  'longitude': -74.9692065},
#                  'display_phone': '(856) 437-0709',
#                  'distance': 2573.0442243758944,
#                  'id': 'Zr3CwG-1zbXlktQoHjgIOQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ssnAKM6EMTFBUt2U-J5XFQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1940 Olney Ave',
#                               'address2': 'Ste 100',
#                               'address3': '',
#                               'city': 'Cherry Hill',
#                               'country': 'US',
#                               'display_address': ['1940 Olney Ave',
#                                                   'Ste 100',
#                                                   'Cherry Hill, NJ 08003'],
#                               'state': 'NJ',
#                               'zip_code': '08003'},
#                  'name': 'Forgotten Boardwalk Brewing',
#                  'phone': '+18564370709',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 77,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/forgotten-boardwalk-brewing-cherry-hill?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'zeds-beer-bado-brewing-evesham-township',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 39.8921552048509,
#                                  'longitude': -74.9217946980322},
#                  'display_phone': '(856) 872-7632',
#                  'distance': 3923.0391867090043,
#                  'id': '5TJzhqoLXvWXyxHFullsJg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zLgVLA04CQbXOHDHQupxkw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '19 N Maple Ave',
#                               'address2': 'Unit B',
#                               'address3': None,
#                               'city': 'Evesham Township',
#                               'country': 'US',
#                               'display_address': ['19 N Maple Ave',
#                                                   'Unit B',
#                                                   'Evesham Township, NJ 08053'],
#                               'state': 'NJ',
#                               'zip_code': '08053'},
#                  'name': "Zed's Beer Bado Brewing",
#                  'phone': '+18568727632',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 24,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/zeds-beer-bado-brewing-evesham-township?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'jays-elbow-room-maple-shade',
#                  'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#                  'coordinates': {'latitude': 39.93853, 'longitude': -74.97037},
#                  'display_phone': '(856) 235-3687',
#                  'distance': 5480.079751798534,
#                  'id': 'Vz87mSBJUQUEnDsYtkFPfg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sEwFIz3W94B8XtPmFKMI9A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2806 Route 73 N',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Maple Shade',
#                               'country': 'US',
#                               'display_address': ['2806 Route 73 N',
#                                                   'Maple Shade, NJ 08052'],
#                               'state': 'NJ',
#                               'zip_code': '08052'},
#                  'name': "Jay's Elbow Room",
#                  'phone': '+18562353687',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 99,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/jays-elbow-room-maple-shade?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'chickies-and-petes-marlton',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'sportsbars',
#                                  'title': 'Sports Bars'}],
#                  'coordinates': {'latitude': 39.891412, 'longitude': -74.92689},
#                  'display_phone': '(856) 452-5126',
#                  'distance': 3483.2252184634926,
#                  'id': 'kvv4hZ8EUe_sGwcsl-mLQw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FoUSJJILiPObbWCG2mdMPQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '25 NJ-73',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Marlton',
#                               'country': 'US',
#                               'display_address': ['25 NJ-73',
#                                                   'Marlton, NJ 08053'],
#                               'state': 'NJ',
#                               'zip_code': '08053'},
#                  'name': "Chickie's & Pete's",
#                  'phone': '+18564525126',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 84,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/chickies-and-petes-marlton?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'yard-house-moorestown-2',
#                  'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'vegetarian', 'title': 'Vegetarian'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 39.942683769952,
#                                  'longitude': -74.9628652384746},
#                  'display_phone': '(856) 722-5620',
#                  'distance': 5963.0351388471745,
#                  'id': 'JNBuXPEjE3eavcIUvUc49A',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QBM9bgIRcTBmlSSYgQeYkQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '400 Rte 38',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Moorestown',
#                               'country': 'US',
#                               'display_address': ['400 Rte 38',
#                                                   'Moorestown, NJ 08057'],
#                               'state': 'NJ',
#                               'zip_code': '08057'},
#                  'name': 'Yard House',
#                  'phone': '+18567225620',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 351,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/yard-house-moorestown-2?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'the-pour-house-westmont',
#                  'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 39.910558,
#                                  'longitude': -75.050601},
#                  'display_phone': '(856) 869-4600',
#                  'distance': 7475.732147033148,
#                  'id': 'f8MSbvd5JotxsFsS6fbl-Q',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/e1nY241N2_o4G12ImMsmUA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '124 Haddon Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Westmont',
#                               'country': 'US',
#                               'display_address': ['124 Haddon Ave',
#                                                   'Westmont, NJ 08108'],
#                               'state': 'NJ',
#                               'zip_code': '08108'},
#                  'name': 'The Pour House',
#                  'phone': '+18568694600',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 386,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-pour-house-westmont?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': '7-tap-tavern-mount-laurel',
#                  'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 39.9228164800945,
#                                  'longitude': -74.9352104589343},
#                  'display_phone': '(856) 235-2118',
#                  'distance': 4650.542755527036,
#                  'id': 'DOVvbLt2HDGPnVCYU7IL2Q',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aZBOTbha1njXWsomokhJ9Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '200 Country Club Dr',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Mount Laurel',
#                               'country': 'US',
#                               'display_address': ['200 Country Club Dr',
#                                                   'Mount Laurel, NJ 08054'],
#                               'state': 'NJ',
#                               'zip_code': '08054'},
#                  'name': '7 Tap Tavern',
#                  'phone': '+18562352118',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 5,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/7-tap-tavern-mount-laurel?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'tir-na-nog-kitchen-and-irish-pub-cherry-hill',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'irish_pubs', 'title': 'Irish Pub'}],
#                  'coordinates': {'latitude': 39.864049,
#                                  'longitude': -74.964849},
#                  'display_phone': '(856) 520-8312',
#                  'distance': 2781.0683944251164,
#                  'id': 'ODJi28l49yt15sEYqwE6Nw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bALUx-YUounW9xbGyEqETA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '482 E Evesham Rd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Cherry Hill',
#                               'country': 'US',
#                               'display_address': ['482 E Evesham Rd',
#                                                   'Cherry Hill, NJ 08003'],
#                               'state': 'NJ',
#                               'zip_code': '08003'},
#                  'name': 'Tir Na Nog Kitchen & Irish Pub',
#                  'phone': '+18565208312',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 78,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/tir-na-nog-kitchen-and-irish-pub-cherry-hill?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'kings-road-brewing-company-haddonfield',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 39.89787, 'longitude': -75.03281},
#                  'display_phone': '',
#                  'distance': 5645.756369986817,
#                  'id': 'VstEcA4Mpr-Z_Z7YxGonjw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Zl1Ur5J_u7E4YoXV8K1vuA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '127 Kings Hwy E',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Haddonfield',
#                               'country': 'US',
#                               'display_address': ['127 Kings Hwy E',
#                                                   'Haddonfield, NJ 08033'],
#                               'state': 'NJ',
#                               'zip_code': '08033'},
#                  'name': 'Kings Road Brewing Company',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 12,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kings-road-brewing-company-haddonfield?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'p-j-whelihans-pub-restaurant-cherry-hill-cherry-hill-7',
#                  'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 39.90528, 'longitude': -74.97209},
#                  'display_phone': '(856) 424-8844',
#                  'distance': 1847.993138021452,
#                  'id': '6JHO6E6brnJOPK5476QY6A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UVmkc8pioU3RD0P7j0S9tw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1854 E Marlton Pike',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Cherry Hill',
#                               'country': 'US',
#                               'display_address': ['1854 E Marlton Pike',
#                                                   'Cherry Hill, NJ 08034'],
#                               'state': 'NJ',
# ...
#                  'id': 'X0KU6OBAW9I1QFsFBq-Jhg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PrJVmYCqtxZuK7sANoy4pQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '241 White Horse Pike',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Barrington',
#                               'country': 'US',
#                               'display_address': ['241 White Horse Pike',
#                                                   'Barrington, NJ 08007'],
#                               'state': 'NJ',
#                               'zip_code': '08007'},
#                  'name': 'Timeout Entertainment and Grill',
#                  'phone': '+18565477444',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 13,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/timeout-entertainment-and-grill-barrington?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'flying-fish-brewing-co-somerdale',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#                  'coordinates': {'latitude': 39.8536587887811,
#                                  'longitude': -75.0204055374678},
#                  'display_phone': '(856) 504-3442',
#                  'distance': 5991.588405336659,
#                  'id': 'K3rQIh4EXBwCb1xass2k7g',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/L7b7ZZu3W4Ppx5s6dTSdMQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '900 Kennedy Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Somerdale',
#                               'country': 'US',
#                               'display_address': ['900 Kennedy Blvd',
#                                                   'Somerdale, NJ 08083'],
#                               'state': 'NJ',
#                               'zip_code': '08083'},
#                  'name': 'Flying Fish Brewing Co',
#                  'phone': '+18565043442',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 73,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/flying-fish-brewing-co-somerdale?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'otts-voorhees-tavern-voorhees-township-2',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'sportsbars',
#                                  'title': 'Sports Bars'}],
#                  'coordinates': {'latitude': 39.8483192063396,
#                                  'longitude': -74.9789591129339},
#                  'display_phone': '(856) 282-6309',
#                  'distance': 4645.612119029087,
#                  'id': 'ZQauNoMxMbdeq3WpE8PLew',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ia33m-58nKjWosfjbhza8g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '890 Haddonfield Berlin Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Voorhees Township',
#                               'country': 'US',
#                               'display_address': ['890 Haddonfield Berlin Rd',
#                                                   'Voorhees Township, NJ '
#                                                   '08043'],
#                               'state': 'NJ',
#                               'zip_code': '08043'},
#                  'name': "Ott's Voorhees Tavern",
#                  'phone': '+18562826309',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 53,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/otts-voorhees-tavern-voorhees-township-2?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'millers-ale-house-mt-laurel-mt-laurel-2',
#                  'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'seafood', 'title': 'Seafood'}],
#                  'coordinates': {'latitude': 39.9315248006976,
#                                  'longitude': -74.9596953392029},
#                  'display_phone': '(856) 722-5690',
#                  'distance': 4756.635698026076,
#                  'id': '7McQCpcpjyAA_TaQPlsirg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YD5HN5k0E_lMv-GktPdVLQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '554 Fellowship Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Mt Laurel',
#                               'country': 'US',
#                               'display_address': ['554 Fellowship Rd',
#                                                   'Mt Laurel, NJ 08054'],
#                               'state': 'NJ',
#                               'zip_code': '08054'},
#                  'name': "Miller's Ale House - Mt Laurel",
#                  'phone': '+18567225690',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 261,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/millers-ale-house-mt-laurel-mt-laurel-2?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'marlton-tavern-marlton',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 39.89015, 'longitude': -74.91717},
#                  'display_phone': '(856) 985-2424',
#                  'distance': 4312.949883363522,
#                  'id': '4ZkITH77rCe0h6hEm9VV4g',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2qgraAAlm-qmEn9iLyJWwQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '65 E Main St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Marlton',
#                               'country': 'US',
#                               'display_address': ['65 E Main St',
#                                                   'Marlton, NJ 08053'],
#                               'state': 'NJ',
#                               'zip_code': '08053'},
#                  'name': 'Marlton Tavern',
#                  'phone': '+18569852424',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 70,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/marlton-tavern-marlton?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'iron-hill-brewery-and-restaurant-voorhees',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 39.851736,
#                                  'longitude': -74.998271},
#                  'display_phone': '(856) 545-9009',
#                  'distance': 4917.461510267735,
#                  'id': 'T-uphPk44OFt6sR8F-0uHA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WmmiqMzq6giNTUodV3U4xA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '13107 Town Center Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Voorhees',
#                               'country': 'US',
#                               'display_address': ['13107 Town Center Blvd',
#                                                   'Voorhees, NJ 08043'],
#                               'state': 'NJ',
#                               'zip_code': '08043'},
#                  'name': 'Iron Hill Brewery & Restaurant',
#                  'phone': '+18565459009',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 223,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/iron-hill-brewery-and-restaurant-voorhees?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'kaminskis-sports-bar-and-grill-cherry-hill',
#                  'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 39.8919, 'longitude': -75.01846},
#                  'display_phone': '(856) 428-2555',
#                  'distance': 4331.415433338389,
#                  'id': 'DI4OK-UVHZqCwpCE8jX2ow',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/i1z6UdoGXj8suZt9FBCI4A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1424 Brace Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Cherry Hill',
#                               'country': 'US',
#                               'display_address': ['1424 Brace Rd',
#                                                   'Cherry Hill, NJ 08034'],
#                               'state': 'NJ',
#                               'zip_code': '08034'},
#                  'name': "Kaminski's Sports Bar and Grill",
#                  'phone': '+18564282555',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 91,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kaminskis-sports-bar-and-grill-cherry-hill?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'iron-hill-brewery-and-restaurant-maple-shade',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 39.947169125849,
#                                  'longitude': -74.973307338977},
#                  'display_phone': '(856) 273-0300',
#                  'distance': 6466.278602676599,
#                  'id': '5KS5b5-ip8znhJS_CYdzeQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C-C8MLVF4vV8vv8R8RusPQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '124 East Kings Hwy',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Maple Shade',
#                               'country': 'US',
#                               'display_address': ['124 East Kings Hwy',
#                                                   'Maple Shade, NJ 08052'],
#                               'state': 'NJ',
#                               'zip_code': '08052'},
#                  'name': 'Iron Hill Brewery & Restaurant',
#                  'phone': '+18562730300',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 299,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/iron-hill-brewery-and-restaurant-maple-shade?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'brewers-towne-tavern-westmont',
#                  'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#                  'coordinates': {'latitude': 39.908546,
#                                  'longitude': -75.046142},
#                  'display_phone': '(856) 854-5545',
#                  'distance': 7032.041763757266,
#                  'id': '9I15RdM5Dvgx-fSgC5LW8A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UDuE1F4QtZYM5AqWeRCH5w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '239 Haddon Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Westmont',
#                               'country': 'US',
#                               'display_address': ['239 Haddon Ave',
#                                                   'Westmont, NJ 08108'],
#                               'state': 'NJ',
#                               'zip_code': '08108'},
#                  'name': 'Brewers Towne Tavern',
#                  'phone': '+18568545545',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 42,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/brewers-towne-tavern-westmont?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'},
#                 {'alias': 'the-taproom-and-grill-haddon-township',
#                  'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#                                 {'alias': 'pubs', 'title': 'Pubs'}],
#                  'coordinates': {'latitude': 39.9001269395344,
#                                  'longitude': -75.0530919996334},
#                  'display_phone': '(856) 854-4255',
#                  'distance': 7393.199106058444,
#                  'id': 'ho7GpzsVdUi9ndG3Z4LuuA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UP-4KmZ3oErvTOk0K4uy_w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '427 W Crystal Lake Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Haddon Township',
#                               'country': 'US',
#                               'display_address': ['427 W Crystal Lake Ave',
#                                                   'Haddon Township, NJ 08033'],
#                               'state': 'NJ',
#                               'zip_code': '08033'},
#                  'name': 'The Taproom & Grill',
#                  'phone': '+18568544255',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 94,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-taproom-and-grill-haddon-township?adjust_creative=1GwZyE0zIjSujpHtlMnodQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1GwZyE0zIjSujpHtlMnodQ'}],
#  'region': {'center': {'latitude': 39.88918063619376,
#                        'longitude': -74.96761322021484}},
#  'total': 76}
# Uh oh

# %%
Bar_data.head
# Out:
# <bound method NDFrame.head of Empty DataFrame
# Columns: [Zip Code, Bar Review Count, Bar Average Rating, Bar Weighted Rating]
# Index: []>
