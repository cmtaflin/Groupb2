# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from pprint import pprint
import uszipcode
import numpy as numpy
import time
import requests
import json
import warnings
warnings.filterwarnings('ignore')

# %%
CDIA_df = pd.read_csv("data\\U.S._Chronic_Disease_Indicators__Alcohol.csv",header=0, thousands=r',')
CDIA_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource    Topic  \
# 0       2016     2016           US  United States      BRFSS  Alcohol
# 1       2016     2016           AL        Alabama      BRFSS  Alcohol
# 2       2016     2016           AK         Alaska      BRFSS  Alcohol
# 3       2016     2016           AZ        Arizona      BRFSS  Alcohol
# 4       2016     2016           AR       Arkansas      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      NaN             %
# 1  Binge drinking prevalence among adults aged >=...      NaN             %
# 2  Binge drinking prevalence among adults aged >=...      NaN             %
# 3  Binge drinking prevalence among adults aged >=...      NaN             %
# 4  Binge drinking prevalence among adults aged >=...      NaN             %
#
#   DataValueTypeID        ...        TopicID QuestionID  ResponseID LocationID  \
# ...

# %%
# mean of the BingeDrinking Data by state and year
binge_df = CDIA_df.loc[  (CDIA_df['QuestionID'] =='ALC3_0') 
| (CDIA_df['QuestionID'] =='ALC4_0')
| (CDIA_df['QuestionID'] =='ALC2_2')
| (CDIA_df['QuestionID'] =='ALC2_3')
| (CDIA_df['QuestionID'] =='ALC2_1')
| (CDIA_df['QuestionID'] =='ALC2_2')].groupby(['LocationDesc','YearStart'])['DataValueAlt'].mean()
binge_df
# Out:
# LocationDesc   YearStart
# Alabama        2011          9.505556
#                2012          8.617647
#                2013          7.961765
#                2014          8.124242
#                2015          8.538235
#                2016          9.729730
# Alaska         2011         12.452778
#                2012         10.745946
#                2013         13.831707
#                2014         12.810811
#                2015         12.414286
#                2016         11.297222
# Arizona        2011         10.765714
#                2012          9.310811
#                2013         10.076471
#                2014          9.241463
#                2015         10.360000
#                2016         10.730233
# Arkansas       2011         10.396552
#                2012          8.606250
#                2013         10.188571
#                2014          9.991429
#                2015         10.351724
#                2016         10.984375
# ...

# %%
avg_bingeing = binge_df.unstack(1)
avg_bingeing
# Out:
# YearStart                  2011       2012       2013       2014       2015  \
# LocationDesc
# Alabama                9.505556   8.617647   7.961765   8.124242   8.538235
# Alaska                12.452778  10.745946  13.831707  12.810811  12.414286
# Arizona               10.765714   9.310811  10.076471   9.241463  10.360000
# Arkansas              10.396552   8.606250  10.188571   9.991429  10.351724
# California            10.757143   9.937037  10.634091   9.888636   9.771154
# Colorado              11.787179  11.553846  12.385000  10.802564  10.935897
# Connecticut           10.848649  10.553846  11.430000  10.344737  10.184091
# Delaware              12.357143  12.205263  10.613158  10.856250  10.548387
# District of Columbia  15.078947  13.263889  13.061538  13.520588  15.764103
# Florida               10.370455  10.082500   9.767308   9.623256  10.465909
# Georgia               10.714634   9.478947   9.207895   9.575000  10.105556
# ...

# %%
#mean of the Heavy drinking by state and year
heavy_df = CDIA_df.loc[  (CDIA_df['QuestionID'] =='ALC5_1') 
| (CDIA_df['QuestionID'] =='ALC5_2')].groupby(['LocationDesc','YearStart'])['DataValueAlt'].mean()
heavy_df
# Out:
# LocationDesc   YearStart
# Alabama        2011          5.015385
#                2012          5.176923
#                2013          4.241667
#                2014          4.616667
#                2015          5.038462
#                2016          5.492308
# Alaska         2011          7.008333
#                2012          6.133333
#                2013          8.633333
#                2014          8.750000
#                2015          7.913333
#                2016          6.581818
# Arizona        2011          6.691667
#                2012          5.025000
#                2013          6.412500
#                2014          5.507143
#                2015          5.000000
#                2016          6.242857
# Arkansas       2011          6.290000
#                2012          4.241667
#                2013          5.250000
#                2014          5.118182
#                2015          5.588889
#                2016          5.255556
# ...

# %%
avg_heavy_drinking = heavy_df.unstack(1)
avg_heavy_drinking
# Out:
# YearStart                  2011      2012      2013       2014       2015  \
# LocationDesc
# Alabama                5.015385  5.176923  4.241667   4.616667   5.038462
# Alaska                 7.008333  6.133333  8.633333   8.750000   7.913333
# Arizona                6.691667  5.025000  6.412500   5.507143   5.000000
# Arkansas               6.290000  4.241667  5.250000   5.118182   5.588889
# California             5.942105  5.463158  6.336842   6.068750   5.415789
# Colorado               6.883333  5.750000  7.187500   6.576923   5.525000
# Connecticut            7.250000  6.014286  6.672727   6.009091   5.692857
# Delaware               7.041667  7.050000  6.308333   4.958333   5.466667
# District of Columbia  10.314286  9.200000  7.250000  10.116667  10.946154
# Florida                6.928571  6.835714  6.405556   6.457143   5.728571
# Georgia                6.083333  5.076923  4.707692   5.123077   5.841667
# ...

# %%
# plot graph for binging
#Plot graph for heavy drinking
